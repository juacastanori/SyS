# %% [markdown]
# <a href="https://colab.research.google.com/github/juacastanori/SyS/blob/main/Taller3_parte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.33_7b5c43f8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.33_3f8378f0.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.34_9a7d2d47.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.34_e71ba414.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.34_89b10f9c.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.35_37da1004.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.34_d037c5b4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.35_a645d878.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.35_745cc690.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing() #importar sympy y declarar variables simbólicas

t = sym.symbols('t', real=True)
s = sym.symbols('s', complex=True)
#integral transformada de laplace
X = sym.integrate(sym.DiracDelta(t)*sym.exp(-s*t), (t, -sym.oo, sym.oo))
X
# Out:
# 1

# %%
s0 = sym.symbols('s0', complex=True)
#utilizamos la función de transformada de Laplace de sympy
X, a, cond = sym.laplace_transform(sym.exp(-s0*t), t, s)
X, a, cond
# Out:
# ⎛  1                  ⎞
# ⎜──────, -re(s₀), True⎟
# ⎝s + s₀               ⎠

# %% [markdown]
# Primero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.35_47f1caa9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.14.34_88d980ff.jpg](data:image/jpeg;base64,...)

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing()

s = sym.symbols('s', complex=True)
t = sym.symbols('t', real=True)

X = (2*s**2 + 14*s + 124)/(s**3 + 8 * s**2 + 46*s + 68)
X
# Out:
#      2
#   2⋅s  + 14⋅s + 124
# ─────────────────────
#  3      2
# s  + 8⋅s  + 46⋅s + 68

# %%
sym.inverse_laplace_transform(X, s, t).simplify() #sin embargo puede ser más costoso computacionalmente
# Out:
#   ⎛   t           ⎞  -3⋅t
# 2⋅⎝2⋅ℯ  - cos(5⋅t)⎠⋅ℯ    ⋅θ(t)

# %% [markdown]
# Segundo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.14.33_27776330.jpg](data:image/jpeg;base64,...)

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing()

s = sym.symbols('s', complex=True)
t = sym.symbols('t', real=True)

X = 1/((s+1)*(s+2)**2)
X
# Out:
#        1
# ────────────────
#                2
# (s + 1)⋅(s + 2)

# %%
sym.inverse_laplace_transform(X, s, t).simplify() #sin embargo puede ser más costoso computacionalmente
# Out:
# ⎛      t    ⎞  -2⋅t
# ⎝-t + ℯ  - 1⎠⋅ℯ    ⋅θ(t)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Imagen de WhatsApp 2024-09-09 a las 21.07.36_0bd75951.jpg](data:image/jpeg;base64,...)
